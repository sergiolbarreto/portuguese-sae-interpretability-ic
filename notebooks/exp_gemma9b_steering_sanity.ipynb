# %% [markdown]
# # Sanity check B.2.3 — feature alvo está ativa no último token do benchmark?
#
# Diagnóstico posicional: para cada item do benchmark de 228 itens, captura a ativação da feature alvo no último token e no argmax token.

# %%
# Setup identical ao B.2.3 — ver exp_gemma9b_steering.ipynb
# Este notebook verifica se as features 3595 (L20) e 9886 (L31)
# estão ativas no token de predição do benchmark.
# Resultado: gemma9b_steering_sanity.json
