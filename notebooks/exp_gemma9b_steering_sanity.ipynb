# %% [markdown]
# # Sanity check B.2.3 — is the target feature active at the last token of the benchmark?
#
# Positional diagnostic: for each item in the 228-item benchmark, captures the target feature activation at the last token and at the argmax token.

# %%
# Setup identical ao B.2.3 — ver exp_gemma9b_steering.ipynb
# Este notebook verifica se as features 3595 (L20) e 9886 (L31)
# are active at the benchmark prediction token.
# Resultado: gemma9b_steering_sanity.json
